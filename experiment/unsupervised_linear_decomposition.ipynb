# %% [markdown]
# # 教師なし線形次元削減

# %%
from numpy.random import randn,rand
import numpy as np
import matplotlib.pyplot as plt
import sys,os
sys.path.append(os.pardir)
from tools.models.decomposition.lpp import LPP
from tools.models.decomposition.pca import PCA
from tools.utils.plot.unlabeled_data_plot import UnlabeledDataPlotter

# %%
def generate(n,seed=None):
    np.random.seed=seed
    xa1=2*randn(n)
    xa2=randn(n)
    xb1=2*randn(n)
    xb2=2*np.round(rand(n))-1+ randn(n)/3
    x_a=np.array([xa1,xa2])
    x_b=np.array([xb1,xb2])
    return x_a.T,x_b.T

# %%
N=100
SEED=0

# %%
X_a,X_b=generate(N,SEED)

# %%
plotter=UnlabeledDataPlotter()

# %%
plotter.plot(X_a,"generated(A type)")

# %%
plotter.plot(X_b,"generated(B type)")

# %%
pca=PCA(n_components=1)
lpp=LPP(n_components=1)

# %%
pca_eig_a=pca.fit(X_a)[0]
pca_eig_b=pca.fit(X_b)[0]

# %%
theta_pca_a=(0,1/pca_eig_a[0],-1/pca_eig_a[1])
theta_pca_b=(0,1/pca_eig_b[0],-1/pca_eig_b[1])

# %%
plotter.plot(X_a,title="Result (PCA, A type)",theta=theta_pca_a)

# %%
plotter.plot(X_b,title="Result (PCA,B type)",theta=theta_pca_b)

# %%
lpp.fit(X_a),lpp.fit(X_b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ff6d49b2272b> in <module>()
# ----> 1 lpp.fit(X_a),lpp.fit(X_b)
#
# ~/github/ml-tools/tools/models/decomposition/lpp.py in fit(self, X)
#      17         A = X.T @ L @ X
#      18         B = X.T @ D @ X
# ---> 19         eig_val, eig_vec = scipy.linalg.eig(A, B)
#      20         components = []
#      21         for i in range(self.n_components):  # normalize
#
# AttributeError: module 'scipy' has no attribute 'linalg'
